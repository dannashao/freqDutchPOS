# %% [markdown]
# # Prepositions, Conjunctions, Pronouns

# %%
from wordlist import print_by_POS

# %% [markdown]
# ## Prepositions

# %%
print_by_POS('prep')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## Conjunctions

# %%
print_by_POS('conj')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## Pronoun

# %%
print_by_POS('pron', sort ='alpha')
# Out:
# <style type="text/css">
# ...
